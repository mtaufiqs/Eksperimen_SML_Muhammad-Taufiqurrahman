# %%
from automate_Muhammad_Taufiqurrahman import preprocess_data
import pandas as pd

df = pd.read_csv("Telco-Customer-Churn.csv")
hasil = preprocess_data(df)
print("\n✅ Data hasil preprocessing (5 baris pertama):")
# Out:
# === 🚀 AUTOMATED PREPROCESSING PIPELINE ===
#
# 📍 Menangani Missing Values...
# ✅ Penanganan missing values selesai.
#
# 📍 Menghapus Data Duplikat...
# Tidak ditemukan data duplikat.
#
#
# 📍 Normalisasi & Standarisasi Fitur...
# ✅ Normalisasi dan standarisasi selesai.
#
# 📍 Deteksi dan Penanganan Outlier...
# ✅ Outlier selesai ditangani.
#
# 📍 Encoding Data Kategorikal...
# ✅ Encoding selesai.
#
# 📍 Melakukan Binning Data Numerik...
# ✅ Binning selesai.
#
# 🎯 Semua tahapan preprocessing selesai.
# Data siap digunakan untuk pelatihan model.
#
#
# ✅ Data hasil preprocessing (5 baris pertama):

# %%
hasil['cleaned'].head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No       1           No
# 1  5575-GNVDE    Male            0.0      No         No      34          Yes
# 2  3668-QPYBK    Male            0.0      No         No       2          Yes
# 3  7795-CFOCW    Male            0.0      No         No      45           No
# 4  9237-HQITU  Female            0.0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
hasil['normalized'].head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0  7590-VHVEG  Female            0.0     Yes         No  0.013889
# 1  5575-GNVDE    Male            0.0      No         No  0.472222
# 2  3668-QPYBK    Male            0.0      No         No  0.027778
# 3  7795-CFOCW    Male            0.0      No         No  0.625000
# 4  9237-HQITU  Female            0.0      No         No  0.027778
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
hasil['standardized'].head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0  7590-VHVEG  Female      -0.439916     Yes         No -1.277445
# 1  5575-GNVDE    Male      -0.439916      No         No  0.066327
# 2  3668-QPYBK    Male      -0.439916      No         No -1.236724
# 3  7795-CFOCW    Male      -0.439916      No         No  0.514251
# 4  9237-HQITU  Female      -0.439916      No         No -1.236724
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
hasil['encoded'].head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0    0.000142       0            0.0        1           0       1
# 1    0.000142       1            0.0        0           0      34
# 2    0.000142       1            0.0        0           0       2
# 3    0.000142       1            0.0        0           0      45
# 4    0.000142       0            0.0        0           0       2
#
#    PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  ...  \
# 0             0                 1           29.85      0.000142  ...
# 1             1                 0           56.95      0.000142  ...
# 2             1                 1           53.85      0.000142  ...
# 3             0                 0           42.30      0.000142  ...
# 4             1                 1           70.70      0.000142  ...
#
#    StreamingMovies_No  StreamingMovies_No internet service  \
# 0                True                                False
# ...

# %%
hasil['binned'].head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0    0.000142       0            0.0        1           0       1
# 1    0.000142       1            0.0        0           0      34
# 2    0.000142       1            0.0        0           0       2
# 3    0.000142       1            0.0        0           0      45
# 4    0.000142       0            0.0        0           0       2
#
#    PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  ...  \
# 0             0                 1           29.85      0.000142  ...
# 1             1                 0           56.95      0.000142  ...
# 2             1                 1           53.85      0.000142  ...
# 3             0                 0           42.30      0.000142  ...
# 4             1                 1           70.70      0.000142  ...
#
#    Contract_One year  Contract_Two year  \
# 0              False              False
# 1               True              False
# ...
